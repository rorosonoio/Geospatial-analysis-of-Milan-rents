# %%
import requests 
import pandas as pd
from bs4 import BeautifulSoup as bs

# %% [markdown]
# After downloading the needed packages, the data is imported from the Italian renting website immobiliare.it, which lists rent announcements of all italian cities.

# %%
r_im = requests.get('https://www.immobiliare.it/mercato-immobiliare/lombardia/milano/') 
soup_im = bs(r_im.content) 

#print('Classes of each table:')
#for table in soup_im.find_all('table'):
#    print(table.get('class'))

tab = soup_im.find('table', class_='nd-table')
immobiliare = pd.read_html(str(tab))[0]
#print(immobiliare)
# Out:
#                                     Zone  Vendita(€/m²)  Affitto(€/m²)
# 0                                 Centro          9.889           2887
# 1         Arco della Pace, Arena, Pagano          8.774           2312
# 2                       Genova, Ticinese          7.349           2216
# 3         Quadronno, Palestro, Guastalla          8.542           2449
# 4        Garibaldi, Moscova, Porta Nuova          9.344           2781
# 5   Fiera, Sempione, City Life, Portello          6.594           2155
# 6                                Navigli          6.022            217
# 7        Porta Romana, Cadore, Montenero          6.542           2096
# 8            Porta Venezia, Indipendenza          7.352           2241
# 9                   Centrale, Repubblica          6.347           2256
# 10                 Cenisio, Sarpi, Isola          6.127           2209
# 11        Viale Certosa, Cascina Merlata          3.712           1816
# 12                   Bande Nere, Inganni          4.367           1731
# 13                     Famagosta, Barona          3.979           1857
# 14           Abbiategrasso, Chiesa Rossa          4.080           1867
# 15                  Porta Vittoria, Lodi          4.824           1933
# 16         Cimiano, Crescenzago, Adriano          3.434           1726
# 17                     Bicocca, Niguarda          3.516           1655
# 18                    Solari, Washington          6.487           2249
# 19                        Affori, Bovisa          3.325           1807
# 20                      San Siro, Trenno          3.585           1669
# 21               Bisceglie, Baggio, Olmi          2.657           1452
# 22                  Ripamonti, Vigentino          4.160           1844
# 23                             Forlanini          3.173           1559
# 24                     Città Studi, Susa          5.298           1881
# 25                    Maggiolina, Istria          4.832           1819
# 26                       Precotto, Turro          3.904           1827
# 27                       Udine, Lambrate          4.008           1708
# 28                     Pasteur, Rovereto          4.465           2011
# 29            Ponte Lambro, Santa Giulia          2.891           1554
# 30                    Corvetto, Rogoredo          3.727           1904
# 31                      Napoli, Soderini          4.883           1755

# %%
#changing the column names to English and something more easy to use
immobiliare = immobiliare.rename(columns = {'Vendita(€/m²)':'Sale', 'Affitto(€/m²)' : 'Rent'})

# %%
#the rent is written without the decimals, as italian decimal numbers are written with a comma, instead of the dot.
#This function fixes this issue
def fixrent(number):
    n1 = str(number)
    n2 = list(n1)
    n2.insert(2,'.')
    return float(''.join(n2))

print(fixrent(2345))
# Out:
# 23.45

# %%
immobiliare.Rent = immobiliare.Rent.apply(lambda x: fixrent(x)) #previous function is applied

# %%
#same issue with the sales numbers, now fixed
def fixsale(number):
    number = number*1000
    return int(number)

immobiliare.Sale = immobiliare.Sale.apply(lambda x: fixsale(x))
immobiliare
# Out:
#                                     Zone  Sale   Rent
# 0                                 Centro  9889  28.87
# 1         Arco della Pace, Arena, Pagano  8774  23.12
# 2                       Genova, Ticinese  7349  22.16
# 3         Quadronno, Palestro, Guastalla  8542  24.49
# 4        Garibaldi, Moscova, Porta Nuova  9344  27.81
# 5   Fiera, Sempione, City Life, Portello  6594  21.55
# 6                                Navigli  6022  21.70
# 7        Porta Romana, Cadore, Montenero  6542  20.96
# 8            Porta Venezia, Indipendenza  7352  22.41
# 9                   Centrale, Repubblica  6347  22.56
# 10                 Cenisio, Sarpi, Isola  6127  22.09
# 11        Viale Certosa, Cascina Merlata  3712  18.16
# 12                   Bande Nere, Inganni  4367  17.31
# 13                     Famagosta, Barona  3979  18.57
# 14           Abbiategrasso, Chiesa Rossa  4080  18.67
# 15                  Porta Vittoria, Lodi  4824  19.33
# 16         Cimiano, Crescenzago, Adriano  3434  17.26
# 17                     Bicocca, Niguarda  3516  16.55
# 18                    Solari, Washington  6487  22.49
# 19                        Affori, Bovisa  3325  18.07
# 20                      San Siro, Trenno  3585  16.69
# 21               Bisceglie, Baggio, Olmi  2657  14.52
# 22                  Ripamonti, Vigentino  4160  18.44
# 23                             Forlanini  3173  15.59
# 24                     Città Studi, Susa  5298  18.81
# 25                    Maggiolina, Istria  4832  18.19
# 26                       Precotto, Turro  3904  18.27
# 27                       Udine, Lambrate  4008  17.08
# 28                     Pasteur, Rovereto  4465  20.11
# 29            Ponte Lambro, Santa Giulia  2891  15.54
# 30                    Corvetto, Rogoredo  3727  19.04
# 31                      Napoli, Soderini  4883  17.55

# %%
#immobiliare.to_csv('dataImmobiliare.csv', index=False)
